# %% [markdown]
# # How to Use `Tensorflow 2`
#
# ### Loading Libraries

# %%
# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# Data Visualization
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D  

# Warnings
import warnings

# Path
from pathlib import Path
from copy import deepcopy

# Scikit-Learn
import sklearn
from sklearn.datasets import make_circles 

# Tensorflow
import tensorflow as tf


from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
from tensorflow.keras.callbacks import TensorBoard

# %%
sns.set_style('white')

np.random.seed(seed=42)

warnings.filterwarnings('ignore')

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using GPU

# %%
results_path = Path('results')

if not results_path.exists():
    results_path.mkdir()

# %% [markdown]
# ### Input Data
#
# #### Generating Random Data

# %%
N = 50000

factor = 0.1

noise = 0.1

# %%
X, y = make_circles(
    n_samples=N,
    shuffle=True,
    factor=factor,
    noise=noise)

# %%
Y = np.zeros((N, 2))

for c in [0, 1]:
    Y[y == c, c] = 1

# %%
f'Shape of: X: {X.shape} | Y: {Y.shape} | y: {y.shape}'
# Out:
# 'Shape of: X: (50000, 2) | Y: (50000, 2) | y: (50000,)'

# %% [markdown]
# #### Visualizing Data

# %%
sns.scatterplot(x=X[:, 0], 
                y=X[:, 1], 
                hue=y,
               style=y,
               markers=['_', '+']);

plt.grid()
plt.show()

# %% [markdown]
# ### Building Keras Model
#
# #### Defining Architecture

# %%
model = Sequential([
    Dense(units=3, input_shape=(2,), name='hidden'),
    Activation('sigmoid', name='logistic'),
    Dense(2, name='output'),
    Activation('softmax', name='softmax'),
])
# Out:
# 2025-04-30 10:03:22.160773: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-04-30 10:03:22.160826: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2025-04-30 10:03:22.160840: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# 2025-04-30 10:03:22.160915: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-30 10:03:22.160940: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden (Dense)                  │ (None, 3)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ logistic (Activation)           │ (None, 3)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax (Activation)            │ (None, 2)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17 (68.00 B)
#  Trainable params: 17 (68.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Compiling Model

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# #### Tensorboard Callback

# %%
tb_callback = TensorBoard(log_dir=results_path / 'tensorboard', 
                          histogram_freq=1, 
                          write_graph=True, 
                          write_images=True)

# %% [markdown]
# #### Training Model

# %%
training=model.fit(X, 
          Y, 
          epochs=50,
          validation_split=.2,
          batch_size=128, 
          verbose=1, 
          callbacks=[tb_callback])
# Out:
# Epoch 1/50
# 2025-04-30 10:03:31.703411: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4999 - loss: 0.7599 - val_accuracy: 0.5075 - val_loss: 0.6944
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4324 - loss: 0.6930 - val_accuracy: 0.5209 - val_loss: 0.6896
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5725 - loss: 0.6884 - val_accuracy: 0.7252 - val_loss: 0.6850
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7057 - loss: 0.6826 - val_accuracy: 0.7924 - val_loss: 0.6762
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8065 - loss: 0.6722 - val_accuracy: 0.8215 - val_loss: 0.6609
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8337 - loss: 0.6557 - val_accuracy: 0.8449 - val_loss: 0.6399
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8507 - loss: 0.6332 - val_accuracy: 0.8552 - val_loss: 0.6128
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8633 - loss: 0.6034 - val_accuracy: 0.8598 - val_loss: 0.5800
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8670 - loss: 0.5701 - val_accuracy: 0.8669 - val_loss: 0.5432
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8752 - loss: 0.5331 - val_accuracy: 0.8773 - val_loss: 0.5030
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8844 - loss: 0.4923 - val_accuracy: 0.8894 - val_loss: 0.4613
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8975 - loss: 0.4493 - val_accuracy: 0.9015 - val_loss: 0.4191
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9088 - loss: 0.4069 - val_accuracy: 0.9145 - val_loss: 0.3778
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9174 - loss: 0.3683 - val_accuracy: 0.9288 - val_loss: 0.3384
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9340 - loss: 0.3295 - val_accuracy: 0.9516 - val_loss: 0.3014
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9582 - loss: 0.2933 - val_accuracy: 0.9797 - val_loss: 0.2673
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9852 - loss: 0.2594 - val_accuracy: 0.9946 - val_loss: 0.2359
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9951 - loss: 0.2287 - val_accuracy: 0.9989 - val_loss: 0.2073
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9985 - loss: 0.1996 - val_accuracy: 0.9994 - val_loss: 0.1813
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9992 - loss: 0.1764 - val_accuracy: 0.9994 - val_loss: 0.1582
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9996 - loss: 0.1529 - val_accuracy: 0.9997 - val_loss: 0.1372
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.1333 - val_accuracy: 0.9997 - val_loss: 0.1188
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9998 - loss: 0.1164 - val_accuracy: 0.9997 - val_loss: 0.1023
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0991 - val_accuracy: 0.9997 - val_loss: 0.0882
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0868 - val_accuracy: 0.9997 - val_loss: 0.0759
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0740 - val_accuracy: 0.9998 - val_loss: 0.0652
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0637 - val_accuracy: 0.9998 - val_loss: 0.0561
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0543 - val_accuracy: 0.9998 - val_loss: 0.0482
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0467 - val_accuracy: 0.9998 - val_loss: 0.0415
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0407 - val_accuracy: 0.9998 - val_loss: 0.0358
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0349 - val_accuracy: 0.9999 - val_loss: 0.0309
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0302 - val_accuracy: 0.9999 - val_loss: 0.0267
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0261 - val_accuracy: 0.9998 - val_loss: 0.0232
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 0.9998 - val_loss: 0.0202
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.9998 - val_loss: 0.0176
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0171 - val_accuracy: 0.9998 - val_loss: 0.0154
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.9998 - val_loss: 0.0135
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.9998 - val_loss: 0.0119
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9998 - val_loss: 0.0105
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9998 - val_loss: 0.0094
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9998 - val_loss: 0.0084
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9998 - val_loss: 0.0075
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9998 - val_loss: 0.0068
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9998 - val_loss: 0.0061
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9998 - val_loss: 0.0056
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9998 - val_loss: 0.0051
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9998 - val_loss: 0.0047
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9998 - val_loss: 0.0043
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0040 - val_accuracy: 0.9998 - val_loss: 0.0040
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9998 - val_loss: 0.0038

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14,4))

pd.DataFrame(training.history)[['accuracy', 'val_accuracy']].plot(ax=axes[0])
pd.DataFrame(training.history)[['loss', 'val_loss']].plot(ax=axes[1])
sns.despine()
fig.tight_layout();

plt.grid()
plt.show()

# %% [markdown]
# #### Getting Weights

# %%
hidden = model.get_layer('hidden').get_weights()

# %%
[t.shape for t in hidden]
# Out:
# [(2, 3), (3,)]

# %% [markdown]
# #### Plotting Decision Boundary

# %%
n_vals = 200

x1 = np.linspace(-1.5, 1.5, num=n_vals)
x2 = np.linspace(-1.5, 1.5, num=n_vals)

xx, yy = np.meshgrid(x1, x2)

# %%
X_ = np.array([xx.ravel(), yy.ravel()]).T

# %%
y_hat = np.argmax(model.predict(X_), axis=1)
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 1s 747us/step

# %%
cmap = ListedColormap([sns.xkcd_rgb["pale red"],
                       sns.xkcd_rgb["denim blue"]])


plt.contourf(xx, yy, y_hat.reshape(n_vals, -1), cmap=cmap, alpha=.25)

data = pd.DataFrame(X, columns=['$x_1$', '$x_2$']).assign(Class=pd.Series(y).map({0:'negative', 1:'positive'}))
sns.scatterplot(x='$x_1$', y='$x_2$', hue='Class', data=data, style=y, markers=['_', '+'], legend=False)
sns.despine()
plt.title('Decision Boundary');
plt.grid()

plt.show()

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir results/tensorboard/
