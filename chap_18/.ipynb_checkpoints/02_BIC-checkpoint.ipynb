# %% [markdown]
# # Basic Image Classification with Feedforward NN and LetNet5
#
# #### Loading Libraries

# %%
# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# Data Visualization
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# Path 
from pathlib import Path
from random import randint

# TensorFlow
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, 
                                     AveragePooling2D, 
                                     Dense, 
                                     Dropout, 
                                     Flatten)

# %%
# %matplotlib inline

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')

if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using GPU

# %%
sns.set_style('whitegrid')

# %%
results_path = Path('results')

mnist_path = results_path / 'mnist'

if not mnist_path.exists():
    mnist_path.mkdir(parents=True)

# %% [markdown]
# ### Loading MNIST Database

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("The MNIST database has a training set of %d examples." % len(X_train))
print("The MNIST database has a test set of %d examples." % len(X_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# The MNIST database has a training set of 60000 examples.
# The MNIST database has a test set of 10000 examples.

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# ### Visualizing Data
#
# #### Visualizing 1st 10 Training Images

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(20, 8))

axes = axes.flatten()
for i, ax in enumerate(axes):
    ax.imshow(X_train[i], cmap='gray')
    ax.axis('off')
    ax.set_title('Digit: {}'.format(y_train[i]), fontsize=16)
fig.suptitle('First 10 Digits', fontsize=20)
fig.tight_layout()
fig.subplots_adjust(top=.9)
plt.show()

# %% [markdown]
# #### Showing Random Image in Detail

# %%
fig, ax = plt.subplots(figsize = (14, 14)) 

i = randint(0, len(X_train))
img = X_train[i]

ax.imshow(img, cmap='gray')
ax.set_title('Digit: {}'.format(y_train[i]), fontsize=16)

width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        ax.annotate('{:2}'.format(img[x][y]), 
                    xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

plt.show()

# %% [markdown]
# ### Preparing Data
#
# #### Rescaling Pixel Values

# %%
X_train = X_train.astype('float32')/255

X_test = X_test.astype('float32')/255

# %% [markdown]
# #### One-Hot Label Encoding using Keras

# %%
print('Integer-valued labels:')

print(y_train[:10])
# Out:
# Integer-valued labels:
# [5 0 4 1 9 2 1 3 1 4]

# %% [markdown]
# ### Feed-Forward NN
#
# #### Model Architecture

# %%
ffnn = Sequential([
    Flatten(input_shape=X_train.shape[1:]),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])
# Out:
# /opt/anaconda3/envs/MLAT/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-05-01 12:16:28.061730: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-05-01 12:16:28.061773: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2025-05-01 12:16:28.061781: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# 2025-05-01 12:16:28.061807: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-01 12:16:28.061826: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
ffnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 669,706 (2.55 MB)
#  Trainable params: 669,706 (2.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Compiling Model

# %%
ffnn.compile(loss='sparse_categorical_crossentropy', 
              optimizer='rmsprop', 
              metrics=['accuracy'])

# %% [markdown]
# ### Calculating Baseline Classification Accuracy

# %%
# Evaluating Test Accuracy
baseline_accuracy = ffnn.evaluate(X_test, y_test, verbose=0)[1]

print(f'Test accuracy: {baseline_accuracy:.2%}')
# Out:
# 2025-05-01 12:18:43.638580: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# Test accuracy: 6.12%

# %% [markdown]
# #### Callback for Model Persistence

# %%
ffn_path = mnist_path / 'ffn.best.hdf5'

# %%
# checkpointer = ModelCheckpoint(filepath=ffn_path.as_posix(), 
#                                verbose=1, 
#                                save_best_only=True)

# %% [markdown]
# #### Early Stopping Callback

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=20)

# %% [markdown]
# #### Training The Model

# %%
epochs = 100

batch_size = 32

# %%
ffnn_history = ffnn.fit(X_train,
                        y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_split=0.2,
                        callbacks=[early_stopping],
                        verbose=1,
                        shuffle=True)
# Out:
# Epoch 1/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7813 - loss: 1.4872 - val_accuracy: 0.8507 - val_loss: 4.3983
# Epoch 2/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7554 - loss: 13.7365 - val_accuracy: 0.8336 - val_loss: 16.5216
# Epoch 3/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7563 - loss: 39.3844 - val_accuracy: 0.8362 - val_loss: 40.0112
# Epoch 4/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7541 - loss: 78.7130 - val_accuracy: 0.8587 - val_loss: 48.6769
# Epoch 5/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7565 - loss: 124.6455 - val_accuracy: 0.8429 - val_loss: 80.6158
# Epoch 6/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7544 - loss: 186.2476 - val_accuracy: 0.8508 - val_loss: 117.2187
# Epoch 7/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7616 - loss: 247.7271 - val_accuracy: 0.8594 - val_loss: 139.1740
# Epoch 8/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7627 - loss: 324.2323 - val_accuracy: 0.8447 - val_loss: 240.0696
# Epoch 9/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7645 - loss: 406.3110 - val_accuracy: 0.8023 - val_loss: 374.3207
# Epoch 10/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7675 - loss: 512.9799 - val_accuracy: 0.8413 - val_loss: 328.1424
# Epoch 11/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7695 - loss: 604.8284 - val_accuracy: 0.8543 - val_loss: 373.3693
# Epoch 12/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7670 - loss: 783.1470 - val_accuracy: 0.8554 - val_loss: 429.1315
# Epoch 13/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7701 - loss: 892.0748 - val_accuracy: 0.8351 - val_loss: 655.9446
# Epoch 14/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7745 - loss: 1036.8625 - val_accuracy: 0.8486 - val_loss: 620.2576
# Epoch 15/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7719 - loss: 1202.0909 - val_accuracy: 0.8153 - val_loss: 806.4072
# Epoch 16/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7762 - loss: 1333.7701 - val_accuracy: 0.8239 - val_loss: 1046.9904
# Epoch 17/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7769 - loss: 1480.6699 - val_accuracy: 0.8353 - val_loss: 1042.0022
# Epoch 18/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7775 - loss: 1643.5553 - val_accuracy: 0.8496 - val_loss: 1070.5194
# Epoch 19/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7736 - loss: 1883.8956 - val_accuracy: 0.8600 - val_loss: 1000.3430
# Epoch 20/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7704 - loss: 2146.3374 - val_accuracy: 0.8451 - val_loss: 1325.2814
# Epoch 21/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7707 - loss: 2334.0269 - val_accuracy: 0.8674 - val_loss: 1130.2643

# %% [markdown]
# #### Plotting CV Results

# %%
pd.DataFrame(ffnn_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(14,4))
sns.despine();
plt.show()

# %% [markdown]
# #### Loading The Best Model

# %%
# ffnn.load_weights(ffn_path.as_posix())

# %% [markdown]
# #### Test Classification Accuracy

# %%
ffnn_accuracy = ffnn.evaluate(X_test, y_test, verbose=0)[1]

print(f'Test accuracy: {ffnn_accuracy:.2%}')
# Out:
# Test accuracy: 86.63%

# %% [markdown]
# ### LeNet5

# %%
K.clear_session()

# %% [markdown]
# #### Model Architecture

# %%
lenet5 = Sequential([
    Conv2D(filters=6,
           kernel_size=5,
           activation='relu',
           input_shape=(28, 28, 1),
           name='CONV1'),
    AveragePooling2D(pool_size=(2, 2),
                     strides=(1, 1),
                     padding='valid',
                     name='POOL1'),
    Conv2D(filters=16, kernel_size=(5, 5), activation='tanh', name='CONV2'),
    AveragePooling2D(pool_size=(2, 2), strides=(2, 2), name='POOL2'),
    Conv2D(filters=120, kernel_size=(5, 5), activation='tanh', name='CONV3'),
    Flatten(name='FLAT'),
    Dense(units=84, activation='tanh', name='FC6'),
    Dense(units=10, activation='softmax', name='FC7')
])
# Out:
# /opt/anaconda3/envs/MLAT/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
lenet5.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ CONV1 (Conv2D)                  │ (None, 24, 24, 6)      │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL1 (AveragePooling2D)        │ (None, 23, 23, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV2 (Conv2D)                  │ (None, 19, 19, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL2 (AveragePooling2D)        │ (None, 9, 9, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV3 (Conv2D)                  │ (None, 5, 5, 120)      │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FLAT (Flatten)                  │ (None, 3000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC6 (Dense)                     │ (None, 84)             │       252,084 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC7 (Dense)                     │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 303,626 (1.16 MB)
#  Trainable params: 303,626 (1.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
lenet5.compile(loss='sparse_categorical_crossentropy',
               optimizer='SGD',
               metrics=['accuracy'])

# %% [markdown]
# #### Defining Checkpoint Callback

# %%
lenet_path = mnist_path / 'lenet.best.hdf5'

# %%
# checkpointer = ModelCheckpoint(filepath=lenet_path.as_posix(),
#                                verbose=1,
#                                save_best_only=True)

# %% [markdown]
# ### Training Model

# %%
lenet_history = lenet5.fit(
    X_train.reshape(-1, 28, 28, 1),
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,  # use 0 to train on all data
    callbacks=[early_stopping],
    verbose=1,
    shuffle=True)
# Out:
# Epoch 1/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7657 - loss: 0.8332 - val_accuracy: 0.9386 - val_loss: 0.2213
# Epoch 2/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.
100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9988 - loss: 0.0080 - val_accuracy: 0.9876 - val_loss: 0.0426
# Epoch 43/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9991 - loss: 0.0079 - val_accuracy: 0.9877 - val_loss: 0.0427
# Epoch 44/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9990 - loss: 0.0076 - val_accuracy: 0.9883 - val_loss: 0.0414
# Epoch 45/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9993 - loss: 0.0074 - val_accuracy: 0.9882 - val_loss: 0.0409
# Epoch 46/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9992 - loss: 0.0071 - val_accuracy: 0.9883 - val_loss: 0.0415
# Epoch 47/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9993 - loss: 0.0067 - val_accuracy: 0.9877 - val_loss: 0.0424
# Epoch 48/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9994 - loss: 0.0066 - val_accuracy: 0.9883 - val_loss: 0.0407
# Epoch 49/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9995 - loss: 0.0061 - val_accuracy: 0.9883 - val_loss: 0.0412
# Epoch 50/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9994 - loss: 0.0059 - val_accuracy: 0.9884 - val_loss: 0.0412
# Epoch 51/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9995 - loss: 0.0062 - val_accuracy: 0.9880 - val_loss: 0.0414
# Epoch 52/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9995 - loss: 0.0056 - val_accuracy: 0.9885 - val_loss: 0.0415
# Epoch 53/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9995 - loss: 0.0054 - val_accuracy: 0.9879 - val_loss: 0.0420
# Epoch 54/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9995 - loss: 0.0054 - val_accuracy: 0.9879 - val_loss: 0.0415
# Epoch 55/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0049 - val_accuracy: 0.9885 - val_loss: 0.0407
# Epoch 56/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9995 - loss: 0.0050 - val_accuracy: 0.9878 - val_loss: 0.0413
# Epoch 57/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9995 - loss: 0.0052 - val_accuracy: 0.9886 - val_loss: 0.0415
# Epoch 58/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0046 - val_accuracy: 0.9882 - val_loss: 0.0414
# Epoch 59/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9996 - loss: 0.0045 - val_accuracy: 0.9881 - val_loss: 0.0412
# Epoch 60/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9996 - loss: 0.0045 - val_accuracy: 0.9886 - val_loss: 0.0407
# Epoch 61/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9996 - loss: 0.0044 - val_accuracy: 0.9883 - val_loss: 0.0413
# Epoch 62/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9996 - loss: 0.0044 - val_accuracy: 0.9879 - val_loss: 0.0414
# Epoch 63/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0041 - val_accuracy: 0.9891 - val_loss: 0.0406
# Epoch 64/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9998 - loss: 0.0040 - val_accuracy: 0.9884 - val_loss: 0.0415
# Epoch 65/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9996 - loss: 0.0038 - val_accuracy: 0.9893 - val_loss: 0.0406
# Epoch 66/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0038 - val_accuracy: 0.9888 - val_loss: 0.0412
# Epoch 67/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0037 - val_accuracy: 0.9887 - val_loss: 0.0410
# Epoch 68/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9996 - loss: 0.0037 - val_accuracy: 0.9887 - val_loss: 0.0409
# Epoch 69/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0036 - val_accuracy: 0.9887 - val_loss: 0.0410
# Epoch 70/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0035 - val_accuracy: 0.9886 - val_loss: 0.0413
# Epoch 71/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0034 - val_accuracy: 0.9887 - val_loss: 0.0411
# Epoch 72/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9998 - loss: 0.0031 - val_accuracy: 0.9889 - val_loss: 0.0411
# Epoch 73/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0033 - val_accuracy: 0.9881 - val_loss: 0.0418
# Epoch 74/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9998 - loss: 0.0030 - val_accuracy: 0.9886 - val_loss: 0.0408
# Epoch 75/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9998 - loss: 0.0031 - val_accuracy: 0.9888 - val_loss: 0.0412
# Epoch 76/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0031 - val_accuracy: 0.9887 - val_loss: 0.0412
# Epoch 77/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9998 - loss: 0.0029 - val_accuracy: 0.9887 - val_loss: 0.0409
# Epoch 78/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9999 - loss: 0.0028 - val_accuracy: 0.9892 - val_loss: 0.0406
# Epoch 79/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9999 - loss: 0.0028 - val_accuracy: 0.9889 - val_loss: 0.0410
# Epoch 80/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9999 - loss: 0.0027 - val_accuracy: 0.9890 - val_loss: 0.0410
# Epoch 81/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9999 - loss: 0.0025 - val_accuracy: 0.9888 - val_loss: 0.0412
# Epoch 82/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9998 - loss: 0.0025 - val_accuracy: 0.9891 - val_loss: 0.0408
# Epoch 83/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9999 - loss: 0.0026 - val_accuracy: 0.9892 - val_loss: 0.0410

# %% [markdown]
# #### Plotting CV Results

# %%
pd.DataFrame(lenet_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(14,4))
sns.despine();
plt.show()

# %% [markdown]
# #### Test Classification Accuracy

# %%
lenet_accuracy = lenet5.evaluate(X_test.reshape(-1, 28, 28, 1), y_test, verbose=0)[1]
print('Test accuracy: {:.2%}'.format(lenet_accuracy))
# Out:
# Test accuracy: 98.96%
