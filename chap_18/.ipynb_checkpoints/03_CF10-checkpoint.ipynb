# %% [markdown]
# # CIFAR10 Image Classification
#
# ### Loading Libraries

# %%
# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# Data Visualization
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# Path 
from pathlib import Path
from random import randint

# TensorFlow
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping

# %%
# %matplotlib inline

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')

if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using GPU

# %%
np.random.seed(42)

sns.set_style('whitegrid')

# %%
# results_path = Path('results', 'cifar10')

# if not results_path.exists():
#     results_path.mkdir()

from pathlib import Path

results_path = Path('results', 'cifar10')

if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# ### Loading CIFAR-10 Data

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 93s 1us/step

# %% [markdown]
# #### Visualizing The 1st 30 Training Images

# %%
cifar10_labels = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
}

# %%
num_classes = len(cifar10_labels)

# %%
height, width, channels = X_train.shape[1:]
input_shape = height, width, channels
input_shape
# Out:
# (32, 32, 3)

# %%
fig, axes = plt.subplots(nrows=3, ncols=10, figsize=(20, 5))

axes = axes.flatten()

for i, ax in enumerate(axes):
    ax.imshow(np.squeeze(X_train[i]))
    ax.axis('off')
    ax.set_title(cifar10_labels[y_train[i, 0]])

plt.show()

# %% [markdown]
# #### Rescaling The Images

# %%
X_train = X_train.astype('float32') / 255

X_test = X_test.astype('float32') / 255

# %% [markdown]
# ### Train-Test split

# %%
X_train, X_valid = X_train[5000:], X_train[:5000]

y_train, y_valid = y_train[5000:], y_train[:5000]

# %%
X_train.shape
# Out:
# (45000, 32, 32, 3)

# %%
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
print(X_valid.shape[0], 'validation samples')
# Out:
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### Feed-Forward Neural Network
#
# #### Model Architecture

# %%
mlp = Sequential([
    Flatten(input_shape=input_shape, name='input'),
    Dense(1000, activation='relu', name='hidden_layer_1'),
    Dropout(0.2, name='droput_1'),
    Dense(512, activation='relu', name='hidden_layer_2'),
    Dropout(0.2, name='dropout_2'),
    Dense(num_classes, activation='softmax', name='output')
])
# Out:
# /opt/anaconda3/envs/MLAT/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-05-01 12:47:46.039904: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-05-01 12:47:46.039954: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2025-05-01 12:47:46.039965: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# 2025-05-01 12:47:46.039997: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-01 12:47:46.040030: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
mlp.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (Flatten)                 │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_1 (Dense)          │ (None, 1000)           │     3,073,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ droput_1 (Dropout)              │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 512)            │       512,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,590,642 (13.70 MB)
#  Trainable params: 3,590,642 (13.70 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Compiling Model

# %%
mlp.compile(loss='sparse_categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

# %% [markdown]
# #### Defining Callbacks

# %%
mlp_path = (results_path / 'mlp.weights.best.hdf5').as_posix()

# %%
# checkpointer = ModelCheckpoint(filepath=mlp_path,
#                                verbose=1,
#                                monitor='val_accuracy',
#                                save_best_only=True)

# %%
from tensorflow.keras.callbacks import TensorBoard

tensorboard = TensorBoard(
    log_dir=results_path / 'logs' / 'mlp',
    histogram_freq=1,
    write_graph=True,
    update_freq='epoch'
)

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10)

# %% [markdown]
# ### Training Model

# %%
batch_size = 32

epochs = 100

# %%
mlp_history = mlp.fit(X_train,
                      y_train,
                      batch_size=batch_size,
                      epochs=epochs,
                      validation_data=(X_valid, y_valid),
                      callbacks=[tensorboard, early_stopping],
                      verbose=1,
                      shuffle=True)
# Out:
# Epoch 1/100
# 2025-05-01 12:50:19.537504: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.1234 - loss: 26.7325 - val_accuracy: 0.1790 - val_loss: 12.2552
# Epoch 2/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1458 - loss: 10.5012 - val_accuracy: 0.1590 - val_loss: 7.8526
# Epoch 3/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1418 - loss: 6.6679 - val_accuracy: 0.1460 - val_loss: 7.8565
# Epoch 4/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1470 - loss: 5.7242 - val_accuracy: 0.1040 - val_loss: 6.4992
# Epoch 5/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1445 - loss: 5.8980 - val_accuracy: 0.1360 - val_loss: 10.0683
# Epoch 6/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1504 - loss: 9.1661 - val_accuracy: 0.1334 - val_loss: 10.8878
# Epoch 7/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1569 - loss: 12.7984 - val_accuracy: 0.2244 - val_loss: 13.5976
# Epoch 8/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1674 - loss: 14.2404 - val_accuracy: 0.1714 - val_loss: 9.7776
# Epoch 9/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1653 - loss: 16.5219 - val_accuracy: 0.1522 - val_loss: 19.1792
# Epoch 10/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1655 - loss: 18.8897 - val_accuracy: 0.1776 - val_loss: 16.8135
# Epoch 11/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1749 - loss: 22.5211 - val_accuracy: 0.2150 - val_loss: 16.2914
# Epoch 12/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1730 - loss: 24.7049 - val_accuracy: 0.1112 - val_loss: 29.0843
# Epoch 13/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.1815 - loss: 25.9210 - val_accuracy: 0.1966 - val_loss: 36.6910
# Epoch 14/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.1795 - loss: 27.2706 - val_accuracy: 0.2132 - val_loss: 15.4471
# Epoch 15/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.1771 - loss: 29.0962 - val_accuracy: 0.1706 - val_loss: 29.1541
# Epoch 16/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.1802 - loss: 28.9394 - val_accuracy: 0.1740 - val_loss: 28.9814
# Epoch 17/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.1848 - loss: 31.7416 - val_accuracy: 0.1940 - val_loss: 38.0882

# %% [markdown]
# #### Plotting CV Results

# %%
pd.DataFrame(mlp_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(14, 4))
sns.despine()
plt.show()

# %% [markdown]
# #### Loading Best Model

# %%
# mlp.load_weights(mlp_path)

# %% [markdown]
# #### Test Classification Accuracy

# %%
mlp_accuracy = mlp.evaluate(X_test, y_test, verbose=0)[1]

print('Test accuracy: {:.2%}'.format(mlp_accuracy))
# Out:
# Test accuracy: 19.42%

# %% [markdown]
# ### Convolutional Neural Network

# %%
K.clear_session()

# %% [markdown]
# #### Model Architecture

# %%
cnn = Sequential([
    Conv2D(filters=16,
           kernel_size=2,
           padding='same',
           activation='relu',
           input_shape=input_shape,
           name='CONV1'),
    MaxPooling2D(pool_size=2, name='POOL1'),
    Conv2D(filters=32,
           kernel_size=2,
           padding='same',
           activation='relu',
           name='CONV2'),
    MaxPooling2D(pool_size=2, name='POOL2'),
    Conv2D(filters=64,
           kernel_size=2,
           padding='same',
           activation='relu',
           name='CONV3'),
    MaxPooling2D(pool_size=2, name='POOL3'),
    Dropout(0.3, name='DROP1'),
    Flatten(name='FLAT1'),
    Dense(500, activation='relu', name='FC1'),
    Dropout(0.4, name='DROP2'),
    Dense(10, activation='softmax', name='FC2')
])
# Out:
# /opt/anaconda3/envs/MLAT/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ CONV1 (Conv2D)                  │ (None, 32, 32, 16)     │           208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL1 (MaxPooling2D)            │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV2 (Conv2D)                  │ (None, 16, 16, 32)     │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL2 (MaxPooling2D)            │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV3 (Conv2D)                  │ (None, 8, 8, 64)       │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL3 (MaxPooling2D)            │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DROP1 (Dropout)                 │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FLAT1 (Flatten)                 │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC1 (Dense)                     │ (None, 500)            │       512,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DROP2 (Dropout)                 │ (None, 500)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC2 (Dense)                     │ (None, 10)             │         5,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 528,054 (2.01 MB)
#  Trainable params: 528,054 (2.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Compiling Model

# %%
cnn.compile(loss='sparse_categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

# %% [markdown]
# #### Defining Callbacks

# %%
cnn_path = (results_path / 'cnn.weights.best.hdf5').as_posix()

# %%
# checkpointer = ModelCheckpoint(filepath=cnn_path,
#                                verbose=1,
#                                monitor='val_accuracy',
#                                save_best_only=True)

# %%
from tensorflow.keras.callbacks import TensorBoard

tensorboard = TensorBoard(
    log_dir=results_path / 'logs' / 'cnn',
    histogram_freq=1,
    write_graph=True,
    update_freq='epoch'
)

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10)

# %% [markdown]
# #### Training Model

# %%
batch_size = 32

epochs = 100

# %%
cnn_history = cnn.fit(X_train,
                      y_train,
                      batch_size=batch_size,
                      epochs=epochs,
                      validation_data=(X_valid, y_valid),
                      callbacks=[tensorboard, early_stopping],
                      verbose=2,
                      shuffle=True)
# Out:
# Epoch 1/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.4319 - loss: 1.5637 - val_accuracy: 0.5450 - val_loss: 1.2798
# Epoch 2/100
# 1407/1407 - 13s - 9ms/step - accuracy: 0.5299 - loss: 1.3271 - val_accuracy: 0.5908 - val_loss: 1.1559
# Epoch 3/100
# 1407/1407 - 12s - 9ms/step - accuracy: 0.5479 - loss: 1.3176 - val_accuracy: 0.6068 - val_loss: 1.1178
# Epoch 4/100
# 1407/1407 - 12s - 9ms/step - accuracy: 0.5432 - loss: 1.3756 - val_accuracy: 0.6050 - val_loss: 1.1468
# Epoch 5/100
# 1407/1407 - 13s - 9ms/step - accuracy: 0.5328 - loss: 1.4733 - val_accuracy: 0.5906 - val_loss: 1.2003
# Epoch 6/100
# 1407/1407 - 12s - 9ms/step - accuracy: 0.5226 - loss: 1.6619 - val_accuracy: 0.5596 - val_loss: 1.4848
# Epoch 7/100
# 1407/1407 - 12s - 9ms/step - accuracy: 0.5088 - loss: 1.9711 - val_accuracy: 0.5234 - val_loss: 1.9525
# Epoch 8/100
# 1407/1407 - 13s - 9ms/step - accuracy: 0.5019 - loss: 2.3878 - val_accuracy: 0.6008 - val_loss: 1.6680
# Epoch 9/100
# 1407/1407 - 13s - 9ms/step - accuracy: 0.4963 - loss: 2.9993 - val_accuracy: 0.5594 - val_loss: 2.1075
# Epoch 10/100
# 1407/1407 - 13s - 9ms/step - accuracy: 0.4915 - loss: 4.1392 - val_accuracy: 0.5056 - val_loss: 5.5489
# Epoch 11/100
# 1407/1407 - 12s - 9ms/step - accuracy: 0.4929 - loss: 5.2162 - val_accuracy: 0.5410 - val_loss: 4.0119
# Epoch 12/100
# 1407/1407 - 13s - 9ms/step - accuracy: 0.4963 - loss: 6.5309 - val_accuracy: 0.4766 - val_loss: 7.9530
# Epoch 13/100
# 1407/1407 - 13s - 9ms/step - accuracy: 0.4883 - loss: 9.5657 - val_accuracy: 0.5874 - val_loss: 6.1113

# %% [markdown]
# #### Plotting CV Results

# %%
pd.DataFrame(cnn_history.history)[['accuracy',
                                   'val_accuracy']].plot(figsize=(14, 4))
sns.despine();
plt.show()

# %% [markdown]
# #### Loading Best Model

# %%
# cnn.load_weights(cnn_path)

# %% [markdown]
# #### Test Set Accuracy

# %%
cnn_accuracy = cnn.evaluate(X_test, y_test, verbose=0)[1]

print('Accuracy: {:.2%}'.format(cnn_accuracy))
# Out:
# Accuracy: 58.01%

# %% [markdown]
# #### Evaluating Predictions

# %%
y_hat = cnn.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
fig, axes = plt.subplots(nrows=4, ncols=8, figsize=(20, 8))

axes = axes.flatten()

images = np.random.choice(X_test.shape[0], size=32, replace=False)

for i, (ax, idx) in enumerate(zip(axes, images)):
    ax.imshow(np.squeeze(X_test[idx]))
    ax.axis('off')
    pred_idx, true_idx = np.argmax(y_hat[idx]), np.argmax(y_test[idx])
    if pred_idx == true_idx:
        ax.set_title('{} (✓)'.format(cifar10_labels[pred_idx]), color="green")
    else:
        ax.set_title("{} ({})".format(cifar10_labels[pred_idx],
                                      cifar10_labels[true_idx]),
                     color='red')
plt.show()
# Out:
# /opt/anaconda3/envs/MLAT/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 10003 (\N{CHECK MARK}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### CNN with Image Augmentation
#
# #### Creating & Configuring an Augmented Image Generator

# %%
datagen = ImageDataGenerator(
    width_shift_range=0.1,  
    height_shift_range=0.1, 
    horizontal_flip=True)

# %%
datagen.fit(X_train)

# %% [markdown]
# #### Visualizing Subset of Training Data

# %%
n_images = 6

x_train_subset = X_train[:n_images]

# %%
fig, axes = plt.subplots(nrows=1, ncols=n_images, figsize=(20, 4))

for i, (ax, img) in enumerate(zip(axes, x_train_subset)):
    ax.imshow(img)
    ax.axis('off')
fig.suptitle('Subset of Original Training Images', fontsize=20)
fig.tight_layout()
fig.subplots_adjust(top=.9)
fig.savefig(results_path / 'original_images')

# Augmented Images
fig, axes = plt.subplots(nrows=1, ncols=n_images, figsize=(20, 4))
for x_batch in datagen.flow(x_train_subset, batch_size=n_images,
                            shuffle=False):
    for i, ax in enumerate(axes):
        ax.imshow(x_batch[i])
        ax.axis('off')
#     fig.suptitle('Augmented Images', fontsize=20)
    break
fig.suptitle('Augmented Images', fontsize=20)
fig.tight_layout()
fig.subplots_adjust(top=.9)
fig.savefig(results_path / 'augmented_images')

plt.show()

# %% [markdown]
# ### Defining Callbacks

# %%
K.clear_session()

# %%
cnn_aug_path = (results_path / 'augmented.cnn.weights.best.hdf5').as_posix()

# %%
# checkpointer = ModelCheckpoint(filepath=cnn_aug_path,
#                                verbose=1,
#                                monitor='val_accuracy',
#                                save_best_only=True)

# %%
from tensorflow.keras.callbacks import TensorBoard

tensorboard = TensorBoard(
    log_dir=results_path / 'logs' / 'cnn_aug',
    histogram_freq=1,
    write_graph=True,
    update_freq='epoch'
)

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', 
                               patience=10)

# %% [markdown]
# ### Training Augmented Images

# %%
batch_size = 32

epochs = 100

# %%
cnn_aug_history = cnn.fit(datagen.flow(X_train, y_train, batch_size=batch_size),
                          steps_per_epoch=X_train.shape[0] // batch_size,
                          epochs=epochs,
                          validation_data=(X_valid, y_valid),
                          callbacks=[tensorboard, early_stopping],
                          verbose=2)
# Out:
# Epoch 1/100
# /opt/anaconda3/envs/MLAT/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4377 - loss: 10.3589 - val_accuracy: 0.5324 - val_loss: 7.4179
# Epoch 2/100
# /opt/anaconda3/envs/MLAT/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 1406/1406 - 0s - 352us/step - accuracy: 0.4688 - loss: 9.4000 - val_accuracy: 0.5546 - val_loss: 6.2489
# Epoch 3/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4470 - loss: 11.2425 - val_accuracy: 0.5504 - val_loss: 8.6844
# Epoch 4/100
# 1406/1406 - 1s - 361us/step - accuracy: 0.4688 - loss: 15.1205 - val_accuracy: 0.5422 - val_loss: 9.0145
# Epoch 5/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4411 - loss: 14.2276 - val_accuracy: 0.5100 - val_loss: 13.8961
# Epoch 6/100
# 1406/1406 - 1s - 369us/step - accuracy: 0.6250 - loss: 8.6151 - val_accuracy: 0.4792 - val_loss: 15.5730
# Epoch 7/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4434 - loss: 17.7134 - val_accuracy: 0.5054 - val_loss: 17.0480
# Epoch 8/100
# 1406/1406 - 0s - 349us/step - accuracy: 0.4062 - loss: 18.8774 - val_accuracy: 0.5204 - val_loss: 16.5487
# Epoch 9/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4465 - loss: 21.3786 - val_accuracy: 0.5438 - val_loss: 15.1135
# Epoch 10/100
# 1406/1406 - 1s - 359us/step - accuracy: 0.3750 - loss: 18.9628 - val_accuracy: 0.5618 - val_loss: 14.0989
# Epoch 11/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4455 - loss: 24.8715 - val_accuracy: 0.5316 - val_loss: 23.1877
# Epoch 12/100
# 1406/1406 - 0s - 351us/step - accuracy: 0.4062 - loss: 25.3880 - val_accuracy: 0.5258 - val_loss: 22.6826
# Epoch 13/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4466 - loss: 30.3166 - val_accuracy: 0.5310 - val_loss: 24.3826
# Epoch 14/100
# 1406/1406 - 0s - 348us/step - accuracy: 0.3438 - loss: 31.8293 - val_accuracy: 0.5348 - val_loss: 23.9383
# Epoch 15/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4475 - loss: 35.9125 - val_accuracy: 0.5358 - val_loss: 26.6692
# Epoch 16/100
# 1406/1406 - 0s - 351us/step - accuracy: 0.2812 - loss: 66.7651 - val_accuracy: 0.5048 - val_loss: 30.3157
# Epoch 17/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4519 - loss: 41.1988 - val_accuracy: 0.5334 - val_loss: 37.4421
# Epoch 18/100
# 1406/1406 - 1s - 358us/step - accuracy: 0.4062 - loss: 45.7474 - val_accuracy: 0.5224 - val_loss: 40.2332
# Epoch 19/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4506 - loss: 46.8507 - val_accuracy: 0.5728 - val_loss: 32.4342
# Epoch 20/100
# 1406/1406 - 0s - 345us/step - accuracy: 0.4375 - loss: 54.5831 - val_accuracy: 0.5714 - val_loss: 34.1834
# Epoch 21/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4482 - loss: 58.8035 - val_accuracy: 0.5388 - val_loss: 45.1008
# Epoch 22/100
# 1406/1406 - 0s - 348us/step - accuracy: 0.5000 - loss: 48.0293 - val_accuracy: 0.5258 - val_loss: 46.5958
# Epoch 23/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4517 - loss: 62.3599 - val_accuracy: 0.5696 - val_loss: 35.8697
# Epoch 24/100
# 1406/1406 - 0s - 343us/step - accuracy: 0.4375 - loss: 48.5591 - val_accuracy: 0.5504 - val_loss: 39.4543
# Epoch 25/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4486 - loss: 72.6789 - val_accuracy: 0.5676 - val_loss: 48.0983
# Epoch 26/100
# 1406/1406 - 0s - 345us/step - accuracy: 0.4375 - loss: 63.2372 - val_accuracy: 0.5732 - val_loss: 48.7596
# Epoch 27/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4493 - loss: 85.2951 - val_accuracy: 0.5550 - val_loss: 64.2514
# Epoch 28/100
# 1406/1406 - 0s - 347us/step - accuracy: 0.4688 - loss: 75.5038 - val_accuracy: 0.5482 - val_loss: 68.2109
# Epoch 29/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4522 - loss: 92.6462 - val_accuracy: 0.5600 - val_loss: 57.1180
# Epoch 30/100
# 1406/1406 - 0s - 344us/step - accuracy: 0.4375 - loss: 74.2490 - val_accuracy: 0.5726 - val_loss: 55.4413
# Epoch 31/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4484 - loss: 108.8945 - val_accuracy: 0.6078 - val_loss: 59.8976
# Epoch 32/100
# 1406/1406 - 0s - 350us/step - accuracy: 0.5312 - loss: 92.2677 - val_accuracy: 0.5970 - val_loss: 61.5265
# Epoch 33/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4497 - loss: 119.2685 - val_accuracy: 0.5416 - val_loss: 91.0773
# Epoch 34/100
# 1406/1406 - 0s - 345us/step - accuracy: 0.4375 - loss: 150.3474 - val_accuracy: 0.5494 - val_loss: 87.6485
# Epoch 35/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4501 - loss: 141.6842 - val_accuracy: 0.5194 - val_loss: 124.4625
# Epoch 36/100
# 1406/1406 - 0s - 346us/step - accuracy: 0.5312 - loss: 112.6767 - val_accuracy: 0.5014 - val_loss: 148.3712
# Epoch 37/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4521 - loss: 155.4129 - val_accuracy: 0.5646 - val_loss: 106.3019
# Epoch 38/100
# 1406/1406 - 0s - 346us/step - accuracy: 0.3438 - loss: 197.4510 - val_accuracy: 0.5826 - val_loss: 95.7561
# Epoch 39/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4548 - loss: 180.0634 - val_accuracy: 0.5136 - val_loss: 171.2280
# Epoch 40/100
# 1406/1406 - 0s - 342us/step - accuracy: 0.5625 - loss: 204.6854 - val_accuracy: 0.5028 - val_loss: 189.4462
# Epoch 41/100
# 1406/1406 - 13s - 9ms/step - accuracy: 0.4524 - loss: 195.7977 - val_accuracy: 0.5618 - val_loss: 126.0932

# %% [markdown]
# #### Plotting CV Result

# %%
pd.DataFrame(cnn_aug_history.history)[['accuracy',
                                       'val_accuracy']].plot(figsize=(14, 4))
sns.despine();
plt.show()

# %% [markdown]
# #### Loading Best Model

# %%
# cnn.load_weights(cnn_aug_path)

# %% [markdown]
# #### Test Set Accuracy

# %%
cnn_aug_accuracy = cnn.evaluate(X_test, y_test, verbose=0)[1]

print('Test Accuracy: {:.2%}'.format(cnn_aug_accuracy))
# Out:
# Test Accuracy: 56.32%

# %% [markdown]
# ### AlexNet
#
# #### Defining Architecture

# %%
K.clear_session()

# %%
alexnet = Sequential([

    # 1st Convolutional Layer
    Conv2D(96, (3, 3),
           strides=(2, 2),
           activation='relu',
           padding='same',
           input_shape=input_shape,
           name='CONV_1'),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='POOL_1'),
    BatchNormalization(name='NORM_1'),

    # 2nd Convolutional Layer
    Conv2D(filters=256,
           kernel_size=(5, 5),
           padding='same',
           activation='relu',
           name='CONV2'),
    MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='POOL2'),
    BatchNormalization(name='NORM_2'),

    # 3rd Convolutional Layer
    Conv2D(filters=384,
           kernel_size=(3, 3),
           padding='same',
           activation='relu',
           name='CONV3'),
    # 4th Convolutional Layer
    Conv2D(filters=384,
           kernel_size=(3, 3),
           padding='same',
           activation='relu',
           name='CONV4'),
    # 5th Convolutional Layer
    Conv2D(filters=256,
           kernel_size=(3, 3),
           padding='same',
           activation='relu',
           name='CONV5'),
    MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='POOL5'),
    BatchNormalization(name='NORM_5'),

    # Fully Connected Layers
    Flatten(name='FLAT'),
    Dense(4096, input_shape=(32 * 32 * 3, ), activation='relu', name='FC1'),
    Dropout(0.4, name='DROP1'),
    Dense(4096, activation='relu', name='FC2'),
    Dropout(0.4, name='DROP2'),
    Dense(num_classes, activation='softmax')
])
# Out:
# /opt/anaconda3/envs/MLAT/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /opt/anaconda3/envs/MLAT/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
alexnet.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ CONV_1 (Conv2D)                 │ (None, 16, 16, 96)     │         2,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL_1 (MaxPooling2D)           │ (None, 8, 8, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ NORM_1 (BatchNormalization)     │ (None, 8, 8, 96)       │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV2 (Conv2D)                  │ (None, 8, 8, 256)      │       614,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL2 (MaxPooling2D)            │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ NORM_2 (BatchNormalization)     │ (None, 3, 3, 256)      │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV3 (Conv2D)                  │ (None, 3, 3, 384)      │       885,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV4 (Conv2D)                  │ (None, 3, 3, 384)      │     1,327,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV5 (Conv2D)                  │ (None, 3, 3, 256)      │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL5 (MaxPooling2D)            │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ NORM_5 (BatchNormalization)     │ (None, 1, 1, 256)      │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FLAT (Flatten)                  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC1 (Dense)                     │ (None, 4096)           │     1,052,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DROP1 (Dropout)                 │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC2 (Dense)                     │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DROP2 (Dropout)                 │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        40,970 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,592,330 (82.37 MB)
#  Trainable params: 21,591,114 (82.36 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %% [markdown]
# #### Compiling Model

# %%
alexnet.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])

# %% [markdown]
# #### Defining Callbacks

# %%
alexnet_path = (results_path / 'alexnet.weights.best.hdf5').as_posix()

# %%
# checkpointer = ModelCheckpoint(filepath=alexnet_path,
#                                verbose=1,
#                                monitor='val_accuracy',
#                                save_best_only=True)

# %%
tensorboard = TensorBoard(
    log_dir=results_path / 'logs' / 'alexnet',
    histogram_freq=1,
    write_graph=True,
    update_freq='epoch'
)

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', 
                               mode='max',
                               patience=10)

# %% [markdown]
# #### Training Model

# %%
batch_size = 32

epochs = 100

# %%
alex_history = alexnet.fit(X_train, 
                           y_train,
                           batch_size=batch_size,
                           epochs=epochs,
                           validation_data=(X_valid, 
                                            y_valid),
                           callbacks=[tensorboard, 
                                      early_stopping],
                           verbose=1)
# Out:
# Epoch 1/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 38s 25ms/step - accuracy: 0.1590 - loss: 10.3118 - val_accuracy: 0.2336 - val_loss: 4.1097
# Epoch 2/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.1944 - loss: 6.2230 - val_accuracy: 0.2364 - val_loss: 7.5179
# Epoch 3/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.2163 - loss: 8.9447 - val_accuracy: 0.2504 - val_loss: 7.7672
# Epoch 4/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.2290 - loss: 13.0141 - val_accuracy: 0.1900 - val_loss: 14.5683
# Epoch 5/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.2049 - loss: 17.4196 - val_accuracy: 0.2752 - val_loss: 23.0957
# Epoch 6/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.2699 - loss: 26.1043 - val_accuracy: 0.3358 - val_loss: 31.0092
# Epoch 7/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.3307 - loss: 48.7479 - val_accuracy: 0.3938 - val_loss: 61.1741
# Epoch 8/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.3966 - loss: 83.4434 - val_accuracy: 0.4752 - val_loss: 55.4040
# Epoch 9/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 35s 25ms/step - accuracy: 0.4501 - loss: 87.2231 - val_accuracy: 0.5598 - val_loss: 50.2159
# Epoch 10/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 35s 25ms/step - accuracy: 0.4829 - loss: 85.1100 - val_accuracy: 0.5054 - val_loss: 100.8484
# Epoch 11/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.5057 - loss: 88.6816 - val_accuracy: 0.5090 - val_loss: 101.3323
# Epoch 12/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.5249 - loss: 93.9205 - val_accuracy: 0.4430 - val_loss: 142.1252
# Epoch 13/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 32s 23ms/step - accuracy: 0.5510 - loss: 92.1049 - val_accuracy: 0.5202 - val_loss: 151.9849
# Epoch 14/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 32s 23ms/step - accuracy: 0.5645 - loss: 111.1298 - val_accuracy: 0.5652 - val_loss: 110.6479
# Epoch 15/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 32s 23ms/step - accuracy: 0.5915 - loss: 126.2579 - val_accuracy: 0.5924 - val_loss: 137.9439
# Epoch 16/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 32s 23ms/step - accuracy: 0.6108 - loss: 136.1264 - val_accuracy: 0.5628 - val_loss: 194.9362
# Epoch 17/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.6226 - loss: 176.2793 - val_accuracy: 0.5250 - val_loss: 287.6918
# Epoch 18/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6491 - loss: 211.8217 - val_accuracy: 0.6400 - val_loss: 235.3278
# Epoch 19/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6517 - loss: 289.5139 - val_accuracy: 0.6254 - val_loss: 359.7465
# Epoch 20/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6489 - loss: 525.8644 - val_accuracy: 0.5118 - val_loss: 1625.9529
# Epoch 21/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6026 - loss: 1558.3667 - val_accuracy: 0.5898 - val_loss: 2800.5232
# Epoch 22/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6315 - loss: 2386.5959 - val_accuracy: 0.4890 - val_loss: 7079.3960
# Epoch 23/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.6338 - loss: 3651.5361 - val_accuracy: 0.6306 - val_loss: 3624.7061
# Epoch 24/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6369 - loss: 4395.1509 - val_accuracy: 0.5498 - val_loss: 7301.4590
# Epoch 25/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6442 - loss: 5822.4351 - val_accuracy: 0.5682 - val_loss: 12052.1035
# Epoch 26/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6388 - loss: 8319.1914 - val_accuracy: 0.5918 - val_loss: 12687.0859
# Epoch 27/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6477 - loss: 11302.9844 - val_accuracy: 0.6424 - val_loss: 13140.1055
# Epoch 28/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6308 - loss: 15420.6816 - val_accuracy: 0.6362 - val_loss: 19170.3477
# Epoch 29/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6271 - loss: 23128.2305 - val_accuracy: 0.5580 - val_loss: 29293.4277
# Epoch 30/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.5928 - loss: 35026.6250 - val_accuracy: 0.6044 - val_loss: 34943.6445
# Epoch 31/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6341 - loss: 42157.5938 - val_accuracy: 0.5888 - val_loss: 76009.6953
# Epoch 32/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6436 - loss: 56728.3398 - val_accuracy: 0.5960 - val_loss: 87605.2422
# Epoch 33/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6439 - loss: 75801.4766 - val_accuracy: 0.6010 - val_loss: 101123.2578
# Epoch 34/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6417 - loss: 105382.2656 - val_accuracy: 0.6110 - val_loss: 150172.8594
# Epoch 35/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6494 - loss: 141271.7656 - val_accuracy: 0.6184 - val_loss: 187986.4219
# Epoch 36/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6570 - loss: 192443.0156 - val_accuracy: 0.5782 - val_loss: 269888.6250
# Epoch 37/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6530 - loss: 267277.9062 - val_accuracy: 0.6426 - val_loss: 300423.3125
# Epoch 38/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6599 - loss: 346460.6562 - val_accuracy: 0.6126 - val_loss: 496035.7812
# Epoch 39/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.6587 - loss: 477893.2188 - val_accuracy: 0.6372 - val_loss: 642104.1875
# Epoch 40/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6699 - loss: 614614.3125 - val_accuracy: 0.6400 - val_loss: 726236.1250
# Epoch 41/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6752 - loss: 796872.0000 - val_accuracy: 0.6340 - val_loss: 1124835.3750
# Epoch 42/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6781 - loss: 1015241.8750 - val_accuracy: 0.6590 - val_loss: 1280680.5000
# Epoch 43/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6826 - loss: 1255289.3750 - val_accuracy: 0.6462 - val_loss: 1788281.2500
# Epoch 44/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.6916 - loss: 1523382.7500 - val_accuracy: 0.6372 - val_loss: 2038510.0000
# Epoch 45/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.6905 - loss: 1805710.6250 - val_accuracy: 0.5794 - val_loss: 3197490.2500
# Epoch 46/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.6878 - loss: 2219886.7500 - val_accuracy: 0.6164 - val_loss: 3384582.0000
# Epoch 47/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6936 - loss: 2610091.7500 - val_accuracy: 0.6304 - val_loss: 4446972.5000
# Epoch 48/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6826 - loss: 3291688.5000 - val_accuracy: 0.6798 - val_loss: 3556125.0000
# Epoch 49/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.7020 - loss: 3393905.0000 - val_accuracy: 0.6274 - val_loss: 5199710.5000
# Epoch 50/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.7125 - loss: 3599964.2500 - val_accuracy: 0.6418 - val_loss: 6071652.0000
# Epoch 51/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.7101 - loss: 4421032.0000 - val_accuracy: 0.6496 - val_loss: 7154924.0000
# Epoch 52/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.7177 - loss: 4670663.0000 - val_accuracy: 0.6428 - val_loss: 8670888.0000
# Epoch 53/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 25ms/step - accuracy: 0.7160 - loss: 5537264.0000 - val_accuracy: 0.6096 - val_loss: 11201514.0000
# Epoch 54/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 38s 27ms/step - accuracy: 0.7204 - loss: 6424732.0000 - val_accuracy: 0.6472 - val_loss: 11362835.0000
# Epoch 55/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.7230 - loss: 6776822.5000 - val_accuracy: 0.6340 - val_loss: 14288237.0000
# Epoch 56/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 38s 27ms/step - accuracy: 0.7265 - loss: 7334557.0000 - val_accuracy: 0.6488 - val_loss: 16253613.0000
# Epoch 57/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.7313 - loss: 8078571.5000 - val_accuracy: 0.5808 - val_loss: 27082354.0000
# Epoch 58/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.7192 - loss: 10061688.0000 - val_accuracy: 0.6678 - val_loss: 18079128.0000

# %% [markdown]
# #### Plotting AlexNet Result

# %%
pd.DataFrame(alex_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(14, 5))
sns.despine();
plt.show()

# %%
# alexnet.load_weights(alexnet_path)

# %%
alex_accuracy = alexnet.evaluate(X_test, y_test, verbose=0)[1]

print('Test Accuracy: {:.2%}'.format(alex_accuracy))
# Out:
# Test Accuracy: 65.79%

# %% [markdown]
# ### Comparing Results

# %%
cv_results = pd.DataFrame(
    {'Feed-Forward NN': pd.Series(mlp_history.history['val_accuracy']),
        'CNN': pd.Series(cnn_history.history['val_accuracy']),
        'CNN Aug.': pd.Series(cnn_aug_history.history['val_accuracy']),
        'Alex Net': pd.Series(alex_history.history['val_accuracy'])
    })

# %%
test_accuracy = pd.Series({
    'Feed-Forward NN': mlp_accuracy,
    'CNN': cnn_accuracy,
    'CNN Aug.': cnn_aug_accuracy,
    'Alex Net': alex_accuracy
})

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14, 4))
cv_results.plot(ax=axes[0], title='CV Validation Performance')
test_accuracy.plot.barh(ax=axes[1], xlim=(.3, .8), title='Test Accuracy', color='orangered')
fig.tight_layout()
sns.despine()
fig.savefig(results_path / 'comparison', dpi=300);
plt.show()

# %% [markdown]
# ### TensorBoard visualization

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir results/cifar10/logs
